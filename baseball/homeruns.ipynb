# %%
from __future__ import print_function
import pyball as pb
import pandas as pd
import matplotlib
from bs4 import BeautifulSoup
import mlbgame
import pprint
import sqlite3 as lite

# %%
file = "db/data/raw_data/Batting.csv"

# %%
batting_df = pd.read_csv(file)

# %%
batting_df.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...    RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...    0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...   13.0  8.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...   19.0  3.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...   27.0  1.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...   16.0  6.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
# 2  1.0   2  5.0  NaN  NaN NaN NaN   1.0
# 3  1.0   0  2.0  NaN  NaN NaN NaN   0.0
# 4  2.0   2  1.0  NaN  NaN NaN NaN   0.0
#
# [5 rows x 22 columns]

# %%
batting_df = batting_df.rename(columns={
    "playerID": "Player",
    "yearID": "Year",
    "teamID": "Team",
    "G": "Games Played",
    "AB": "At Bats",
    "R": "Runs",
    "H": "Hits",
    "HR": "Homeruns",
    "RBI": "Runs Batted In",
    "SO": "Strike Outs"})

# %%
batting_df = batting_df.drop(columns=['stint','lgID','2B','3B','SB','CS','IBB','HBP','SH','SF','GIDP'])

# %%
batting_df.head()
# Out:
#       Player  Year Team  Games Played  At Bats  Runs  Hits  Homeruns  \
# 0  abercda01  1871  TRO             1        4     0     0         0
# 1   addybo01  1871  RC1            25      118    30    32         0
# 2  allisar01  1871  CL1            29      137    28    40         0
# 3  allisdo01  1871  WS3            27      133    28    44         2
# 4  ansonca01  1871  RC1            25      120    29    39         0
#
#    Runs Batted In  BB  Strike Outs
# 0             0.0   0          0.0
# 1            13.0   4          0.0
# 2            19.0   2          5.0
# 3            27.0   0          2.0
# 4            16.0   2          1.0

# %%
batting_df.sort_values(by='Homeruns', ascending=False)
# Out:
#            Player  Year Team  Games Played  At Bats  Runs  Hits  Homeruns  \
# 80768   bondsba01  2001  SFN           153      476   129   156        73
# 77405   mcgwima01  1998  SLN           155      509   130   152        70
# 77752    sosasa01  1998  CHN           159      643   134   198        66
# 78721   mcgwima01  1999  SLN           153      521   118   145        65
# 81786    sosasa01  2001  CHN           160      577   146   189        64
# 79069    sosasa01  1999  CHN           162      625   114   180        63
# 41676   marisro01  1961  NYA           161      590   132   159        61
# 22271    ruthba01  1927  NYA           151      540   158   192        60
# 19054    ruthba01  1921  NYA           152      540   177   204        59
# 104124  stantmi03  2017  MIA           159      597   123   168        59
# 87903   howarry01  2006  PHI           159      581   104   182        58
# 27767   greenha01  1938  DET           155      556   144   175        58
# ...

# %%
homeruns_df = batting_df.groupby('Year')['Homeruns']

# %%
homeruns_df.head()
# Out:
# 0          0
# 1          0
# 2          0
# 3          2
# 4          0
# 115        0
# 116        0
# 117        0
# 118        0
# 119        0
# 272        0
# 273        1
# 274        0
# 275        0
# 276        0
# 397        0
# 398        0
# 399        0
# 400        0
# 401        0
# 520        0
# 521        0
# 522        0
# 523        0
# 524        1
# 738        0
# 739        0
# 740        0
# 741        0
# 742        2
#           ..
# 97019      0
# 97020      0
# 97021      2
# 97022      0
# 97023      4
# 98428      0
# 98429      1
# 98430     36
# 98431      0
# 98432      0
# 99863      0
# 99864      0
# 99865     30
# 99866      0
# 99867      6
# 101349     0
# 101350     0
# 101351    25
# 101352     0
# 101353     0
# 102832     0
# 102833    33
# 102834     0
# 102835     0
# 102836     5
# 104326    22
# 104327    26
# 104328    10
# 104329     0
# 104330     0
# Name: Homeruns, Length: 740, dtype: int64
